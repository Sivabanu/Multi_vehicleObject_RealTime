# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivabanu/Multi_vehicleObject_RealTime/blob/main/Multiple_Object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Feb 13 17:38:20 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'	     'Problem Definition.gdoc'
# 'Getting started.pdf'	     'Project Submision.gdoc'
# 'Meeting preparations.gdoc'   SA.zip
# 'MP4 Hashtak'		      TensorFlow-2.x-YOLOv3
# 'My CV and Cover Letter'     'ucan solution - project titles.pdf'
# 'My CV cover letter.gdoc'     Yolo_Multi
# 'My Drive'

# %%
# %cd /content/gdrive/My\ Drive/Yolo_Multi/
# Out:
# /content/gdrive/My Drive/Yolo_Multi

# %%
# !ls
# Out:
# darknet  finalimg.zip  images.zip  yolov3_backup

# %%
# Configure
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/gdrive/My Drive/Yolo_Multi/darknet

# %%
# Compile
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# !echo -e 'classes= 8\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/Yolo_Multi/yolov3_backup' > data/obj.data

# %%
# !cp cfg/yolov3_training.cfg /mydrive/Yolo_Multi/yolov3_backup/yolov3_testing.cfg
# !cp data/obj.names /mydrive/Yolo_Multi/yolov3_backup/classes.txt

# %%
# !mkdir data/obj
# !unzip /mydrive/Yolo_Multi/finalimg.zip -d data/obj
# Out:
# mkdir: cannot create directory ‘data/obj’: File exists
# Archive:  /mydrive/Yolo_Multi/finalimg.zip
#    creating: data/obj/FInalLableing/
#   inflating: data/obj/FInalLableing/0001.jpg
#   inflating: data/obj/FInalLableing/0001.txt
#   inflating: data/obj/FInalLableing/0002.jpg
#   inflating: data/obj/FInalLableing/0002.txt
#   inflating: data/obj/FInalLableing/0003.jpg
#   inflating: data/obj/FInalLableing/0003.txt
#   inflating: data/obj/FInalLableing/0004.jpg
#   inflating: data/obj/FInalLableing/0004.txt
#   inflating: data/obj/FInalLableing/0005.jpg
#   inflating: data/obj/FInalLableing/0005.txt
#   inflating: data/obj/FInalLableing/0006.jpg
#   inflating: data/obj/FInalLableing/0006.txt
#   inflating: data/obj/FInalLableing/0007.jpg
#   inflating: data/obj/FInalLableing/0007.txt
#   inflating: data/obj/FInalLableing/0008.jpg
#   inflating: data/obj/FInalLableing/0008.txt
#   inflating: data/obj/FInalLableing/0009.jpg
#   inflating: data/obj/FInalLableing/0009.txt
# ...

# %%
import glob
images_list = glob.glob("data/obj/*.jpg")
with open("data/train.txt", "w") as f:
    f.write("\n".join(images_list))

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-02-13 18:21:05--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M  41.7MB/s    in 4.1s
#
# 2021-02-13 18:21:09 (37.8 MB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 10010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_training
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg /mydrive/Yolo_Multi/yolov3_backup/yolov3_training_final.weights -dont_show
# Out:
#  CUDA-version: 10010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_training
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
import cv2
import numpy as np

net = cv2.dnn.readNet('/mydrive/Yolo_Multi/yolov3_backup/yolov3_training_final.weights', '/mydrive/Yolo_Multi/yolov3_backup/yolov3_testing.cfg')

classes = []
with open("/mydrive/Yolo_Multi/yolov3_backup/classes.txt", "r") as f:
    classes = f.read().splitlines()

cap = cv2.VideoCapture('/mydrive/Yolo_Multi/test1.mp4')
font = cv2.FONT_HERSHEY_PLAIN
colors = np.random.uniform(0, 255, size=(100, 3))

while True:
    _, img = cap.read()
    height, width, _ = img.shape

    blob = cv2.dnn.blobFromImage(img, 1/255, (416, 416), (0,0,0), swapRB=True, crop=False)
    net.setInput(blob)
    output_layers_names = net.getUnconnectedOutLayersNames()
    layerOutputs = net.forward(output_layers_names)

    boxes = []
    confidences = []
    class_ids = []

    for output in layerOutputs:
        for detection in output:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]
            if confidence > 0.2:
                center_x = int(detection[0]*width)
                center_y = int(detection[1]*height)
                w = int(detection[2]*width)
                h = int(detection[3]*height)

                x = int(center_x - w/2)
                y = int(center_y - h/2)

                boxes.append([x, y, w, h])
                confidences.append((float(confidence)))
                class_ids.append(class_id)

    indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.2, 0.4)

    if len(indexes)>0:
        for i in indexes.flatten():
            x, y, w, h = boxes[i]
            label = str(classes[class_ids[i]])
            confidence = str(round(confidences[i],2))
            color = colors[i]
            cv2.rectangle(img, (x,y), (x+w, y+h), color, 2)
            cv2.putText(img, label + " " + confidence, (x, y+20), font, 2, (255,255,255), 2)

    cv2.imshow('cap', img)
    key = cv2.waitKey(1)
    if key==27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-24-b26794887d7e> in <module>()
#      54             cv2.putText(img, label + " " + confidence, (x, y+20), font, 2, (255,255,255), 2)
#      55
# ---> 56     cv2.imshow('cap', img)
#      57     key = cv2.waitKey(1)
#      58     if key==27:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
